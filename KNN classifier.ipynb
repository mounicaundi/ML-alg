# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('h2vehicle.csv')
df
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %% [raw]
# performing EDA

# %%
df.shape
# Out:
# (381109, 12)

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df.isna().sum()   ### returns how many  (number) of missing values in each column.
                        ##df.isna().any() returns a boolean value for each column.
                       ##  If there is at least one missing value in that column, the result is True.
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
#droping User ID column as it is not an important feature
df.drop('id',axis =1,inplace = True) ## axis is the postion of the coloumn , inplace is the operation

# %%
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   44                1         28.0                   0   > 2 Years
# 1    Male   76                1          3.0                   0    1-2 Year
# 2    Male   47                1         28.0                   0   > 2 Years
# 3    Male   21                1         11.0                   1    < 1 Year
# 4  Female   29                1         41.0                   1    < 1 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0            Yes         40454.0                  26.0      217         1
# 1             No         33536.0                  26.0      183         0
# 2            Yes         38294.0                  26.0       27         1
# 3             No         28619.0                 152.0      203         0
# 4             No         27496.0                 152.0       39         0

# %%
#converting categorical values to numerical
df = pd.get_dummies(df,drop_first= True)

# %%
df.head()
# Out:
#    Age  Driving_License  Region_Code  Previously_Insured  Annual_Premium  \
# 0   44                1         28.0                   0         40454.0
# 1   76                1          3.0                   0         33536.0
# 2   47                1         28.0                   0         38294.0
# 3   21                1         11.0                   1         28619.0
# 4   29                1         41.0                   1         27496.0
#
#    Policy_Sales_Channel  Vintage  Response  Gender_Male  Vehicle_Age_< 1 Year  \
# 0                  26.0      217         1            1                     0
# 1                  26.0      183         0            1                     0
# 2                  26.0       27         1            1                     0
# 3                 152.0      203         0            1                     1
# 4                 152.0       39         0            0                     1
#
#    Vehicle_Age_> 2 Years  Vehicle_Damage_Yes
# ...

# %%
#seperating X and y
X = df.loc[:,['Age','Driving_License','Region_Code','Previously_Insured','Annual_Premium',
              'Policy_Sales_Channel','Vintage','Gender_Male','Vehicle_Age_< 1 Year','Vehicle_Age_> 2 Years',
              'Vehicle_Damage_Yes']].values
y = df.loc[:,['Response']].values

# %%
X
# Out:
# array([[44.,  1., 28., ...,  0.,  1.,  1.],
#        [76.,  1.,  3., ...,  0.,  0.,  0.],
#        [47.,  1., 28., ...,  0.,  1.,  1.],
#        ...,
#        [21.,  1., 30., ...,  1.,  0.,  0.],
#        [68.,  1., 14., ...,  0.,  1.,  1.],
#        [46.,  1., 29., ...,  0.,  0.,  0.]])

# %% [raw]
# ##Feature Scaling
# Whenever we are dealing with KNN algorithm, we should do the feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X
# Out:
# array([[ 0.33377727,  0.04620794,  0.12178446, ..., -0.87278808,
#          4.77586601,  0.99029399],
#        [ 2.39675074,  0.04620794, -1.76787876, ..., -0.87278808,
#         -0.20938611, -1.00980114],
#        [ 0.52718104,  0.04620794,  0.12178446, ..., -0.87278808,
#          4.77586601,  0.99029399],
#        ...,
#        [-1.14898491,  0.04620794,  0.27295751, ...,  1.1457535 ,
#         -0.20938611, -1.00980114],
#        [ 1.88100737,  0.04620794, -0.93642695, ..., -0.87278808,
#          4.77586601,  0.99029399],
#        [ 0.46271311,  0.04620794,  0.19737098, ..., -0.87278808,
#         -0.20938611, -1.00980114]])

# %%
y.shape
# Out:
# (381109, 1)

# %%
#model was expecting a 1d array as input
y = y.reshape(-1)

# %%
y.shape
# Out:
# (381109,)

# %%
#Splitting the data into train and test data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 0, test_size = 0.25)

# %%
#importing classification metrics
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
acc_list = []
err_list = []
acc_list = []
err_list = []
for i in range(1,5):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test,y_pred)
#     print("For k = {}, accuracy = {}".format(i,acc))
    acc_list.append(acc)
    err_list.append(1-acc)

# %%
plt.plot(list(range(1,5)),err_list,c= 'r')
plt.title('Error rate v/s K')
plt.xlabel('K')
plt.ylabel('Error rate')
plt.show()

# %%
acc
# Out:
# 0.8662545393480132

# %%
##k = 7
acc_list = []
err_list = []

model = KNeighborsClassifier(n_neighbors=7)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
acc = accuracy_score(y_test,y_pred)
acc_list.append(acc)
err_list.append(1-acc)

# %%
acc
# Out:
# 0.8604924536619156
